# %%
from gearopt.optim.gearopt_system import gearopt_system

main_config_file = "optimization_config.yaml"

best, logbook = gearopt_system(main_config_file)
# Out:
# differential_evolution step 1: f(x)= 265729.6274962057
# Iter   0 | f = 265729.6275 | conv = 2.754e-02 | x = [15196.13133882]
# differential_evolution step 1: f(x)= 63101.98474458528
# Iter   0 | f = 63101.9847 | conv = 2.870e-02 | x = [12881.04461463]
# differential_evolution step 2: f(x)= 60544.65120706865
# Iter   1 | f = 60544.6512 | conv = 1.761e-02 | x = [11412.22363771]
# differential_evolution step 1: f(x)= 174965.01287960476
# Iter   0 | f = 174965.0129 | conv = 3.017e-02 | x = [14120.92476472]
# differential_evolution step 2: f(x)= 77898.63727937997
# Iter   1 | f = 77898.6373 | conv = 2.341e-02 | x = [11684.84851721]
# differential_evolution step 3: f(x)= 53050.577302207486
# Iter   2 | f = 53050.5773 | conv = 1.359e-02 | x = [11006.9219244]
# differential_evolution step 2: f(x)= 174965.01287960476
# Iter   1 | f = 174965.0129 | conv = 2.761e-02 | x = [14120.92476472]
# differential_evolution step 3: f(x)= 77898.63727937997
# Iter   2 | f = 77898.6373 | conv = 1.929e-02 | x = [11684.84851721]
# differential_evolution step 4: f(x)= 53050.577302207486
# Iter   3 | f = 53050.5773 | conv = 1.206e-02 | x = [11006.9219244]
# differential_evolution step 3: f(x)= 107223.42460868008
# Iter   2 | f = 107223.4246 | conv = 1.947e-02 | x = [13395.2740739]
# differential_evolution step 4: f(x)= 77898.63727937997
# Iter   3 | f = 77898.6373 | conv = 1.929e-02 | x = [11684.84851721]
# differential_evolution step 5: f(x)= 53050.577302207486
# Iter   4 | f = 53050.5773 | conv = 1.206e-02 | x = [11006.9219244]
# Polishing solution with 'L-BFGS-B'
# differential_evolution step 4: f(x)= 107223.42460868008
# Iter   3 | f = 107223.4246 | conv = 1.972e-02 | x = [13395.2740739]
# differential_evolution step 5: f(x)= 72479.62714092222
# Iter   4 | f = 72479.6271 | conv = 1.646e-02 | x = [13059.9561768]
# Polishing solution with 'L-BFGS-B'
# differential_evolution step 5: f(x)= 107223.42460868008
# Iter   4 | f = 107223.4246 | conv = 1.789e-02 | x = [13395.2740739]
# Polishing solution with 'L-BFGS-B'
