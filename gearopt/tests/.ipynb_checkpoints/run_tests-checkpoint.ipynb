# %%
# !pytest -v -s test_gearopt_system.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.3, pytest-7.4.4, pluggy-1.0.0 -- C:\Users\felixcme\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# plugins: anyio-4.2.0
# collecting ... collected 1 item
#
# test_gearopt_stage.py::test_gearopt_stage_runs differential_evolution step 1: f(x)= 117894.36553497461
# Iter   0 | f = 117894.3655 | conv = 3.696e-02 | x = [13560.9874542]
# differential_evolution step 2: f(x)= 117894.36553497461
# Iter   1 | f = 117894.3655 | conv = 2.949e-02 | x = [13560.9874542]
# differential_evolution step 3: f(x)= 117894.36553497461
# Iter   2 | f = 117894.3655 | conv = 2.836e-02 | x = [13560.9874542]
# differential_evolution step 4: f(x)= 117894.36553497461
# Iter   3 | f = 117894.3655 | conv = 2.847e-02 | x = [13560.9874542]
# differential_evolution step 5: f(x)= 117894.36553497461
# ...
