# %%
import sys
!"{sys.executable}" -m pytest -q -v -s -k "unit"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# collected 24 items / 7 deselected / 17 selected
#
# test_unit_calc_geometry.py .
# === Geometry Comparison (KISSsoft vs calc_geometry) ===
#      Parameter   Reference  Calculated  RelError_percent
#       eps_1_sp    0.453000    0.432410          4.545221
# eps_alpha_t_sp    1.333000    1.294241          2.907673
#       eps_2_sp    0.880000    0.861831          2.064705
#       eps_1_rp    1.394000    1.374225          1.418553
#          d_a_p 1552.561000 1550.235474          0.149786
#          d_a_s 1798.263000 1795.936768          0.129360
#    alpha_wt_rp    0.334423    0.334536          0.033790
#    alpha_wt_sp    0.431847    0.431753          0.021736
#       eps_beta    1.545000    1.544712          0.018613
# ...

# %%
!"{sys.executable}" -m pytest -v -s "test_system_gearopt_system.py"
# Out:
# ^C

# %%
!"{sys.executable}" -m pytest -v -s "test_system_gearopt_stage.py"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- C:\Users\felixcme\AppData\Local\anaconda3\envs\gearopt\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# collecting ... collected 1 item
#
# test_system_gearopt_stage.py::test_gearopt_stage_runs 275
# FAILED
#
# ================================== FAILURES ===================================
# ___________________________ test_gearopt_stage_runs ___________________________
#
# self = <scipy.optimize._differentialevolution.DifferentialEvolutionSolver object at 0x00000250C3926490>
# population = array([[0.49206113],
#        [0.88423278],
#        [0.66059737],
#        [0.79606565],
#        [0.84798755],
#        [0.217...[0.36901363],
#        [0.25981349],
#        [0.02805729],
#        [0.40476981],
#        [0.04050606],
#        [0.54856027]])
#
# ...

# %%
!"{sys.executable}" -m pytest -v -s "test_system_stage_feasibility.py"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.3, pytest-7.4.4, pluggy-1.0.0 -- C:\Users\felixcme\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# plugins: anyio-4.2.0
# collecting ... collected 3 items
#
# test_system_stage_feasibility.py::test_candidate_structure PASSED
# test_system_stage_feasibility.py::test_ratio_consistency PASSED
# test_system_stage_feasibility.py::test_adjacency_constraint PASSED
#
# ============================== 3 passed in 0.99s ==============================

# %%
!"{sys.executable}" -m pytest -v -s "test_system_gearopt_continuous_new.py"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- C:\Users\felixcme\AppData\Local\anaconda3\envs\gearopt\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# collecting ... collected 1 item
#
# test_system_gearopt_continuous_new.py::test_continuous_optimization_runs FAILED
#
# ================================== FAILURES ===================================
# ______________________ test_continuous_optimization_runs ______________________
#
# setup_data = {'data': array([[1., 1., 1.]]), 'i_st': 3.6742, 'i_sts': 1, 'opts': {'continuous': {'ctol': '1e-4', 'disp': False, 'ft...axiter': 3, 'mutation': 0.8, ...}, 'ratios': {'disp': True, 'maxiter': 1, 'mutation': 0.05, 'polish': True, ...}}, ...}
#
#     def test_continuous_optimization_runs(setup_data):
#         """Test that optimization runs and returns valid results."""
# ...

# %%
import sys
!"{sys.executable}" -m pytest -v -s "test_unit_calc_yf_case2.py"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.14, pytest-9.0.2, pluggy-1.6.0 -- C:\Users\felixcme\AppData\Local\anaconda3\envs\gearopt\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# collecting ... collected 2 items
#
# test_unit_calc_yf_case2.py::test_calc_yf_basic PASSED
# test_unit_calc_yf_case2.py::test_calc_yf_pdf_reference_comparison
# === calc_yf_hob / calc_yf_shaper PDF Verification (case2) ===
#        Parameter  Reference(PDF)  Calculated  RelError_percent
#           h_Fe_r         59.3800     47.4912           20.0215
#           Y_F_sp          1.0600      1.1785           11.1775
#           s_Fn_r        109.4300     97.6108           10.8007
#            Y_F_s          1.0900      1.2013           10.2145
#              x_r         53.4820     48.8054            8.7442
# ...

# %%
import importlib
import gearopt.geometry.calc_geometry as cg

importlib.reload(cg)

# %run run_calc_yf_case2_check.py
# Out:
# {'a': Array(1259.9979, dtype=float32), 'alpha_t': Array(0.36035633, dtype=float32), 'alpha_wt_rp': Array(0.25052154, dtype=float32), 'alpha_wt_sp': Array(0.3958977, dtype=float32), 'beta_b': Array(0.24567418, dtype=float32), 'd_a_p': Array(1219.0902, dtype=float32), 'd_a_r': Array(3591.2903, dtype=float32), 'd_a_s': Array(1462.5966, dtype=float32), 'd_b_p': Array(1046.2842, dtype=float32), 'd_b_r': Array(3487.614, dtype=float32), 'd_b_s': Array(1278.7919, dtype=float32), 'd_f_p': Array(1039.0902, dtype=float32), 'd_f_r': Array(3771.2903, dtype=float32), 'd_f_s': Array(1282.5966, dtype=float32), 'd_i_p': Array(943.0902, dtype=float32), 'd_i_s': Array(1186.5966, dtype=float32), 'd_o_r': Array(4051.2903, dtype=float32), 'd_p_p': Array(1118.0983, dtype=float32), 'd_p_r': Array(3726.9944, dtype=float32), 'd_p_s': Array(1366.5646, dtype=float32), 'd_pw_p': Array(1133.998, dtype=float32), 'd_pw_r': Array(3599.9941, dtype=float32), 'd_pw_s': Array(1385.9978, dtype=float32), 'eps_1_rp': Array
# ...

# %%
import numpy as np
print(np.rad2deg(1.077015))
print(np.rad2deg(1.0204285))
# Out:
# 61.70841397228236
# 58.466246344865326
