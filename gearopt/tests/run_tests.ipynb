# %%
# !pytest -v -k "unit"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.3, pytest-7.4.4, pluggy-1.0.0 -- C:\Users\felixcme\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# plugins: anyio-4.2.0
# collecting ... collected 20 items / 6 deselected / 14 selected
#
# test_unit_calc_geometry.py::test_calc_geometry_runs PASSED               [  7%]
# test_unit_calc_geometry.py::test_calc_geometry_reference_comparison PASSED [ 14%]
# test_unit_calc_loads_ldd.py::test_calc_loads_ldd_basic PASSED            [ 21%]
# test_unit_calc_loads_ldd.py::test_calc_loads_ldd_reference_comparison PASSED [ 28%]
# test_unit_calc_sf.py::test_calc_sf_basic PASSED                          [ 35%]
# test_unit_calc_sf.py::test_calc_sf_reference_comparison PASSED           [ 42%]
# test_unit_calc_sh.py::test_calc_sh_detailed PASSED                       [ 50%]
# ...

# %%
# !pytest -v -s "test_system_gearopt_system.py"
# Out:
# ^C

# %%
# !pytest -v -s "test_system_gearopt_stage.py"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.3, pytest-7.4.4, pluggy-1.0.0 -- C:\Users\felixcme\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# plugins: anyio-4.2.0
# collecting ... collected 1 item
#
# test_system_gearopt_stage.py::test_gearopt_stage_runs Iteration limit reached    (Exit mode 9)
#             Current function value: 151081.93859974525
#             Iterations: 10
#             Function evaluations: 36
#             Gradient evaluations: 7
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 53189.37305968207
#             Iterations: 6
#             Function evaluations: 10
#             Gradient evaluations: 2
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 83370.05830125045
# ...

# %%
# !pytest -v -s "test_system_stage_feasibility.py"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.3, pytest-7.4.4, pluggy-1.0.0 -- C:\Users\felixcme\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# plugins: anyio-4.2.0
# collecting ... collected 3 items
#
# test_system_stage_feasibility.py::test_candidate_structure PASSED
# test_system_stage_feasibility.py::test_ratio_consistency PASSED
# test_system_stage_feasibility.py::test_adjacency_constraint PASSED
#
# ============================== 3 passed in 0.89s ==============================

# %%
# !pytest -v -s "test_system_gearopt_continuous.py"
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.3, pytest-7.4.4, pluggy-1.0.0 -- C:\Users\felixcme\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\felixcme\OneDrive - NTNU\PostDoc\MADE4WIND\06_Python\gearopt_python
# plugins: anyio-4.2.0
# collecting ... collected 1 item
#
# test_system_gearopt_continuous.py::test_continuous_optimization_runs Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 2131.463507777868
#             Iterations: 9
#             Function evaluations: 65
#             Gradient evaluations: 5
# PASSED
#
# ============================== 1 passed in 1.51s ==============================
