# %%
from gearopt.optim.gearopt_system import gearopt_system

main_config_file = "optimization_config.yaml"

best, logbook = gearopt_system(main_config_file)
# Out:
# Warming up JAX wrappers...
# Warm-up complete.
#
# differential_evolution step 1: f(x)= 1.1339290142059326
# Iter   0 | conv = 7.927e-02 | x = [162.61569938]
# differential_evolution step 2: f(x)= 1.1339290142059326
# Iter   1 | conv = 8.502e-02 | x = [162.61569938]
# differential_evolution step 1: f(x)= 0.4399067759513855
# Iter   0 | conv = 6.799e-02 | x = [31.08987723]
# differential_evolution step 3: f(x)= 1.1339290142059326
# Iter   2 | conv = 1.006e-01 | x = [162.61569938]
# Polishing solution with 'L-BFGS-B'
# differential_evolution step 1: f(x)= 0.18204115331172943
# Iter   0 | conv = 6.488e-02 | x = [207.85932717]
# differential_evolution step 2: f(x)= 0.4399067759513855
# Iter   1 | conv = 7.776e-02 | x = [31.08987723]
